# %%
# %matplotlib inline
import pandas as pd

from shapely.geometry import Polygon, point
from geopandas import GeoSeries, GeoDataFrame, read_file
from pandas import DataFrame
import geopandas as gpd

# %%
points1 = pd.read_csv("2017-01-greater-manchester-street.csv",
                      usecols=['Crime type','LSOA code','Longitude', 'Latitude'])

# %%
points1.head(3)
# Out:
#    Longitude   Latitude  LSOA code                    Crime type
# 0  -2.462774  53.622101  E01012628  Violence and sexual offences
# 1  -2.440584  53.613781  E01004768         Anti-social behaviour
# 2  -2.464422  53.612495  E01004768     Criminal damage and arson

# %%
areas = read_file('data/Clipped.shp')

# %%
areas.plot(figsize=(10,10))

# %%
ViolenceAndSex117_LsoaIMax=read_file('ViolenceAndSex117_LsoaIMax.shp')

# %%
import matplotlib.pyplot as plt
disolved = read_file('data/disolved.shp')
fig, ax = plt.subplots(figsize=(20,20))
ax=ViolenceAndSex117_LsoaIMax.plot(column='LMoranMax', ax=disolved.plot(ax=ax, color="white"))
plt.title('LOCAL MORAN I for Violence And Sex Crimes', size = 30)

# %%
len(AS117_LsoaZMax)
# Out:
# 577
