# %%
# %matplotlib inline
import pysal as ps
import pandas as pd
import numpy as np

from shapely.geometry import Polygon, point
from geopandas import GeoSeries, GeoDataFrame, read_file
from pandas import DataFrame
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
areas = read_file('data/Clipped.shp')

# %%
areas.plot(figsize=(20,20))

# %%
areas3 = read_file('data/england_lsoa_2011.shp')

# %%
areas2.plot(figsize=(20,20))

# %%
areas2.head(1)
# Out:
#     AREA_HECT    LAD11CD LAD11NM     OA11CD RU_DEF_COD RU_DEF_DES  \
# 0  5.39000000  E08000004  Oldham  E00027289         A1     U_MJ_C
#
#                                             geometry
# 0  POLYGON ((391534.614 408179.564, 391533.508 40...

# %%
areas.head(1)
# Out:
#         code                                           geometry  \
# 0  E01005390  POLYGON ((391554.204 408539.202, 391556.496 40...
#
#                          label         name
# 0  E08000004E02001101E01005390  Oldham 004A

# %%
areas3.head(1)
# Out:
#         code                                           geometry  \
# 0  E01000037  POLYGON ((551549.998 187364.637, 551528.633 18...
#
#                          label                       name
# 0  E09000002E02000004E01000037  Barking and Dagenham 003B
